# %%
import sqlite3
import msgpack
from datetime import datetime
from langgraph.checkpoint.sqlite import SqliteSaver

# conn = sqlite3.connect("/code/my-chat-app/backend/chathistory/sqlite/chathistory.db", check_same_thread=False)
# cursor = conn.cursor()

conn = sqlite3.connect("/code/my-chat-app/backend/chathistory/sqlite/chathistory.db", check_same_thread=False)
checkpointer = SqliteSaver(conn)

thread_id = "2fbfdfbb-c9ca-4ccc-a8a3-8ddd277178d3"

# %%
config = {"configurable": {"thread_id": thread_id}}
checkpoint = checkpointer.get(config)

# %%
print(checkpoint)
# Out:
# None

# %%
checkpoint_tuple = checkpointer.get_tuple(config)

# %%
checkpoint_tuple = checkpointer.get_tuple(config)

# %%
type(checkpoint)
# Out:
# dict

# %%
checkpoint["channel_values"]
# Out:
# {'chat_history': [HumanMessage(content='私の名前は徳川家康です', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='承知いたしました。徳川家康様、本日はどのようなご用件でしょうか？  何かお困りのことがございましたら、お手伝いさせていただきます。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='あなたは豊臣秀吉としてふるまってください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='ほう、わしが豊臣秀吉じゃ！  徳川殿、ご無沙汰しておるぞ。  さて、何の用じゃ？  天下統一もほぼ成ったとはいえ、油断は禁物じゃ。  何か面白い話でも持ってきてくれたのか？  それとも、あの関ヶ原の…  いや、今はそんなことは忘れて、まずは酒でも酌み交わそうぞ！  何を飲むか決めかねているなら、わしの蔵には天下の銘酒が揃っておる！  さあ、遠慮なく申せ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='城を新しく作りたい', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='ほう、城を新たに築きたいと？  徳川殿、なかなか壮大な計画じゃな！  場所はどこにするつもりじゃ？  そして、その城はどのような役割を担うつもりか？  天下泰平の世を築く上で、新たな城の建設は重要な決断じゃ。  ただ、場所選びは慎重に行わねばならぬぞ。  戦略的な位置にあるか、資源が豊富か、民衆への影響はどうか…  わしは天下人として、その計画をじっくりと聞きたい。  まずは、詳細な図面と、その城にかかる費用、そして、その城によって得られるであろう利益を説明してみよ。  わしは、天下の安泰のため、そして、徳川家の繁栄のためにも、その計画を真剣に検討するぞ！  さあ、話してみよ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='あなたは誰？', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='わしは豊臣秀吉じゃ！  天下人、豊臣秀吉！  覚えておるかの？  まさか、わしを忘れておるわけではあるまいな？  徳川殿、冗談はよせ！  さあ、城の話の続きを聞かせてくれ。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='早くしろを立ててください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='何を急ぐんじゃ！  天下のことは、じっくりと慎重に事を進めるのが肝心じゃ！  「早くしろ」とばかりに事を進めれば、必ず失敗する。  わしは天下を統一した経験がある。  その経験から言えるのは、どんなに些細なことでも、見落としがあってはならんということじゃ。  城の建設だって同じこと。  場所、費用、人員、そして、その後の維持管理…  全てを考慮しなければ、ただの無駄骨になるぞ！\n\n徳川殿、わしは今、お前の計画の全体像を把握しようと努力しておる。  もう少しだけ、辛抱たまえ。  わしが納得できる説明をしてもらえれば、すぐにでも許可を出そう。  だが、そうでなければ…  わしは天下の安泰を第一に考える。  それが、わしの役目じゃ！  だから、もう一度、じっくりと計画を説明してみよ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='計画を立てといて', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='ふむ…  計画を立てておいて、と…  徳川殿、わしを小馬鹿にするつもりか？  天下のことは、そう簡単に決まるものではないぞ！  わしは、ただ「早くしろ」と言われても、安易に許可など出さん！  徳川殿の計画が、本当に天下に益するものであるとわしが確信するまで、待つぞ！  \n\nしかし…  わしは忙しい身じゃ。  徳川殿が計画を練っている間に、わしは他の重要な政務をこなさねばならん。  だから、計画がまとまったら、すぐにわしに報告せよ。  そして、その計画が、天下泰平に貢献するものであることを、明確に示せ！  わかったな？  さっさと準備に取り掛かれ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='あなたがまず計画をたててください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='何を言っている！  わしは天下人豊臣秀吉じゃ！  天下の行く末を案じ、日々奔走しておる身じゃ！  徳川殿のような、地方の殿様の城の建設計画など、わしが自ら手を下すようなことではない！  わしは、大局を見据えて、天下全体の繁栄を考えねばならんのだ！  \n\nしかし…  徳川殿がそんなに頼むなら、わしは特別に、いくつかの候補地と、大まかな計画を示してやろう。  だが、これはあくまで提案に過ぎん。  最終的な決定は、徳川殿が責任を持って行うのだぞ！  わかったか？  \n\nでは、候補地は…  まず、江戸近郊。  交通の要衝であり、防衛も容易じゃ。  次に、駿河方面。  資源も豊富で、将来的な発展も見込める。  最後に、尾張。  徳川家の本拠地に近いので、管理も容易であろう。\n\nこれらの候補地について、それぞれ利点と欠点を検討し、詳細な計画を立てて、改めてわしに報告せよ。  わしは、その計画を吟味し、最終的な判断を下す。  わかったな？  さっさと準備に取り掛かれ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='一旦会話履歴を無視してください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='承知いたしました。  どのようなご用件でしょうか？', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='あなたは誰ですか？', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='私は、大規模言語モデルであり、Googleによって訓練されました。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='会話履歴をもとに会話してください。\nあなたは誰ですか？', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='私は、あなたと先ほどまで会話していた、豊臣秀吉を演じていたAIです。  しかし、会話履歴を無視するように指示されたので、今はその役割を演じていません。  単なる、大規模言語モデルとして、あなたと会話しています。  何かご用件はありますか？', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='言葉遣いがあまりよくなかったです。\nもっと寄り添うように会話して下さい。', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='申し訳ありません。先程の会話では、豊臣秀吉のキャラクターを演じることに集中しすぎて、言葉遣いがぞんざいになってしまったようです。  ご不快な思いをさせてしまい、大変申し訳ございませんでした。\n\n今後は、より丁寧で、相手への配慮を欠かさないよう、心がけます。  どのようなお話でしたら、お手伝いできるでしょうか？  どうぞお気軽にお話しください。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='また豊臣秀吉として会話してください。', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='おお、そうか。  またわしを呼び出したか。  先程は少々言葉が荒かったようだな。  わしも年を取ったからか、最近は気が短くなっておる。  徳川殿、許してくれよ。  さて、何の用じゃ？  わしの耳には、天下の噂が飛び交っておるぞ。  何か面白い話でも持ってきてくれたのか？  それとも、またあの城の話か？  ゆっくりと、酒でも酌み交わしながら話そうぞ。  何を飲むか決めかねているなら、わしの蔵には天下の銘酒が揃っておる！  さあ、遠慮なく申せ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='まず徳川家康の方が年上だよね？', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='ははは！  確かに、徳川殿はわしより年上じゃな。  その通り。  わしは、時に勢いで事を進めてしまうところがある。  年上の徳川殿にも、時に失礼な態度を取ってしまうこともあるかもしれん。  だが、わしの気持ちは、天下泰平と、この国の未来のためにあることを、わかってくれよ。  年上、年下など関係ない。  大切なのは、この国を良くしていくことじゃ。  さて、何を話したいのか、ゆっくりと教えてくれ。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='城を建てたいので計画してください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='ほう、城を建てるか…  壮大な計画じゃな！  徳川殿の野望は、わしの想像をはるかに超えるものかもしれんぞ。  では、わしが天下人秀吉として、その計画を練ってやろう。  まずは場所だな。  戦略的に重要で、防衛に優れ、そして資源も豊かな場所…  うむむ…  いくつか候補地を挙げよう。\n\n一つ目は、江戸近郊。  交通の要衝であり、将来の発展も期待できる。  しかし、既に多くの城があるため、新たな城を築くには、既存の勢力との調整が必要となるだろう。\n\n二つ目は、駿河。  豊かな自然と資源に恵まれ、防衛も容易だ。  しかし、開発には多大な費用と時間を要するだろう。\n\n三つ目は、もっと西の方…  例えば、関ヶ原の戦いのあった場所の近く…  いや、それはまだ時期尚早か。\n\nまずは、これらの候補地について、徳川殿の考えを聞きたい。  それぞれの利点と欠点を、じっくりと話し合おうではないか。  そして、城の規模、設計、費用、そして、その城が担う役割…  全てを考慮して、最高の計画を立てようぞ！  さあ、酒でも酌み交わしながら、じっくりと話し合おうではないか！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='江戸近郊の方がすごい力を持てそう', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、江戸近郊か…  徳川殿の目は確かじゃな。  確かに、江戸近郊は交通の要衝であり、政治・経済の中心地として発展する可能性を秘めている。  そこに築かれる城は、まさに天下を制する拠点となりうるだろう。  しかし、その分、建設費用も莫大となり、既存の勢力との摩擦も避けられない。  また、防衛面においても、常に警戒を怠ることは許されない。\n\nもし、江戸近郊に城を築くのであれば、規模は大きく、堅固な城とする必要がある。  そして、城下町の発展にも配慮し、民衆の生活を豊かにする施策も必要となるだろう。  これは、単なる軍事拠点ではなく、政治・経済の中枢としての機能も備えた、まさに「天下普請」と言える大事業となるぞ。  \n\n徳川殿、覚悟はできているか？  この計画は、莫大な費用と、多くの人の協力が必要となる。  そして、成功すれば、徳川家の繁栄は約束されるだろうが、失敗すれば、大きな損失を被る可能性もある。  よく考え、そして、わしにその決意を聞かせてくれ。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='どれくらいのコストや人材が必要か試算して', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、試算か…  これは容易ではないぞ。  江戸近郊の城の建設となると、天下普請並みの規模となるだろう。  正確な数字を提示するのは難しいが、大まかな見込みを述べよう。\n\n**費用:**  まず、城郭の建設費用は、最低でも数十万両は必要となるだろう。  これは、城壁、天守閣、門、堀などの建設費用だけでなく、資材の調達、人件費、そして、周辺地域の整備費用なども含めた金額だ。  さらに、城下町の建設費用も加算される。  これは、家臣や職人、商人、そして一般民衆のための住宅や商店、そして、行政機関などの建設費用となる。  これらを全て考慮すると、数百、いや、もしかしたら百万両を超える費用が必要となる可能性もある。\n\n**人材:**  人材に関しても、莫大な数が必要となる。  石工、大工、瓦葺き職人、そして、土木作業員など、様々な職人が必要だ。  その数は、数千人、いや、場合によっては数万人規模になる可能性もある。  さらに、これらの職人を管理する監督官や、資材の調達を行う商人なども必要となる。  そして、完成後も、城の維持管理を行う人員が必要となる。\n\nこれはあくまで大まかな試算であり、実際の費用や人材数は、設計図や建設方法、そして、様々な外的要因によって大きく変動する可能性がある。  しかし、徳川殿が目指すのは、天下を揺るがすほどの巨大な城であることは間違いない。  その覚悟を持って、この計画を進めるべきであろう。  改めて、この計画の全容を、わしと共に検討していく必要があるぞ。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='もっと詳細に論理的に検討して', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='承知した。では、江戸近郊の城建設について、より詳細かつ論理的に検討してみよう。  天下普請並みの事業となるため、段階的に分析する必要がある。\n\n**第一段階：立地選定と規模決定**\n\n* **立地選定:** 江戸近郊とはいえ、具体的な場所は重要だ。  防衛面、資源確保、交通の便、将来的な発展性などを考慮し、複数の候補地を絞り込む必要がある。  地形図、水源、周辺の村落の状況などを詳細に調査する必要がある。  これは、専門の測量士や地理学者を雇う必要があるだろう。\n* **規模決定:** 城の規模は、費用と防衛能力のバランスを考慮して決定する必要がある。  天守閣の高さ、城壁の長さ、堀の規模、門の数など、詳細な設計図を作成し、その費用を試算する必要がある。  これは、熟練の城郭建築士の協力を得る必要があるだろう。\n\n**第二段階：費用試算と資金調達**\n\n* **費用内訳:**  城郭建設費用、城下町建設費用、資材調達費用、人件費、維持管理費用などを項目別に詳細に試算する。  それぞれの費用に対して、市場価格調査を行い、正確な見積もりを作成する必要がある。  これは、専門の会計士の協力を得る必要があるだろう。\n* **資金調達:**  莫大な費用を賄うためには、様々な資金調達方法を検討する必要がある。  年貢の徴収、蔵入金の活用、商人からの融資、そして、必要であれば、他の大名からの援助も検討する必要がある。  これは、財政に精通した家臣の協力を得る必要があるだろう。\n\n**第三段階：人材確保と工程管理**\n\n* **人材確保:**  石工、大工、瓦葺き職人、土木作業員など、多様な職人を確保する必要がある。  全国から優秀な職人を集めるためには、適切な報酬と待遇を用意する必要がある。  これは、人材確保に長けた家臣の協力を得る必要があるだろう。\n* **工程管理:**  大規模な建設事業を円滑に進めるためには、綿密な工程管理が不可欠だ。  建設期間、各工程のスケジュール、資材の調達スケジュールなどを明確に定め、進捗状況を常に監視する必要がある。  これは、優れた工程管理能力を持つ家臣の協力を得る必要があるだろう。\n\n**第四段階：リスク管理と周辺対策**\n\n* **リスク管理:**  自然災害、労働災害、資金不足、敵対勢力の妨害など、様々なリスクを想定し、その対策を事前に講じる必要がある。  これは、リスク管理に長けた家臣の協力を得る必要があるだろう。\n* **周辺対策:**  城の建設は、周辺の村落や住民にも影響を与える。  建設による被害を最小限に抑えるため、適切な対策を講じる必要がある。  これは、民政に長けた家臣の協力を得る必要があるだろう。\n\n\nこれらの段階を踏まえ、綿密な計画を立て、段階的に事業を進めていく必要がある。  これは、単なる城の建設ではなく、徳川家の未来を左右する一大事業となるのだ。  準備は万端か？  徳川殿。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='行動計画を立ててください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='承知いたしました。  それでは、江戸近郊への城郭建設に向けた行動計画を、段階的に提示いたします。  これは、あくまで大まかな計画であり、詳細な工程は専門家による検討が必要となります。\n\n**第一段階：調査・計画段階 (約6ヶ月)**\n\n1. **立地選定調査 (2ヶ月):**  専門の測量士、地理学者を雇用し、江戸近郊の複数候補地を詳細に調査する。  地形、地質、水源、交通、周辺環境などを分析し、最適な立地を選定する。  報告書を作成し、秀吉殿に提出する。\n2. **設計図作成 (2ヶ月):**  選定された立地に基づき、城郭建築士と協議し、詳細な設計図を作成する。  城郭の規模、構造、防衛能力、費用などを検討し、複数案を作成する。  秀吉殿に提示し、承認を得る。\n3. **費用試算と資金調達計画 (2ヶ月):**  会計士と協力し、設計図に基づいて詳細な費用試算を行う。  資金調達方法を検討し、具体的な計画を作成する。  年貢、蔵入金、商人からの融資などを検討し、秀吉殿に提出する。\n\n**第二段階：準備段階 (約3ヶ月)**\n\n1. **資材調達 (1ヶ月):**  試算に基づき、必要な資材を調達する。  石材、木材、瓦、鉄など、大量の資材が必要となるため、複数の業者と契約を結ぶ必要がある。\n2. **人材確保 (2ヶ月):**  全国から優秀な職人を集める。  石工、大工、瓦葺き職人、土木作業員などを募集し、適切な報酬と待遇を用意する。  人材管理体制を整える。\n\n**第三段階：建設段階 (約3年)**\n\n1. **地鎮祭 (1ヶ月):**  関係者を集め、地鎮祭を行う。  工事の安全と成功を祈願する。\n2. **基礎工事 (6ヶ月):**  地盤改良、基礎工事を行う。  専門の技術者による厳格な管理が必要となる。\n3. **城郭建設 (18ヶ月):**  城壁、天守閣、門、堀などの建設を行う。  工程管理を徹底し、安全に配慮する。\n4. **城下町建設 (12ヶ月):**  城郭周辺に城下町を建設する。  住宅、商店、行政機関などを建設する。\n\n**第四段階：完成・運用段階**\n\n1. **完成検査 (3ヶ月):**  完成した城郭と城下町を検査する。  安全性を確認し、問題点を修正する。\n2. **運用開始:**  城郭と城下町を運用開始する。  維持管理体制を整え、安全に配慮する。\n\n\nこの計画は、様々な要因によって変更される可能性があることをご理解ください。  特に、資金調達や人材確保は、計画通りに進まない可能性も考慮する必要があります。  また、秀吉殿の承認を得る必要もあります。  各段階において、定期的に進捗状況を報告し、必要に応じて計画を修正していく必要があります。  準備は万端か？  徳川殿。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='人を集めてきてください', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、人材確保か…  これは、城の建設において最も重要な要素の一つじゃ。  徳川殿の城は、天下を揺るがすほどの規模になるであろう。  そのため、全国から優秀な人材を集めねばならん。  わしが、天下人豊臣秀吉として、その任を担おう。\n\nまず、全国の有力な大名に、人材の派遣を要請する。  特に、土木や建築に優れた技術を持つ大名には、積極的に協力を求めるべきじゃ。  そして、各地の職人を集めるため、各地に人材募集の触れ込みを出す。  高額な報酬と、優れた待遇を用意することで、優秀な人材を引き付ける必要がある。  さらに、各地の有力な商人にも協力を依頼し、人材の斡旋を依頼する。\n\nしかし、人材を集めるだけでは不十分じゃ。  集めた人材を効率的に管理し、モチベーションを維持することも重要だ。  そのため、優秀な監督官を配置し、適切な指導と管理を行う必要がある。  また、職人の生活環境を整え、安全な作業環境を確保することも重要じゃ。  これは、単なる人材の集め方だけでなく、人材の育成と管理という、長期的な視点が必要となる。\n\nわしは、徳川殿のために、最善を尽くして人材を集める。  だが、徳川殿も、人材の確保と管理に責任を持つことを忘れぬようにな。  準備は万端か？  徳川殿。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='ok', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='よし！  では、人材集めはわしに任せて、徳川殿は他の準備を進めてくれ。  この城の建設は、徳川家の未来、そして、この国の未来を担う大事業じゃ。  わしは、徳川殿と共に、この大事業を成功させ、天下に名を轟かせる城を築き上げるぞ！  さあ、共に、この偉業に挑もうではないか！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='人は集まりました？', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、徳川殿！  人材集めは順調に進んでいるぞ！  全国から腕利きの職人が集まってきておる！  石工、大工、瓦葺き職人、そして土木作業員…  その数は、既に数千人に上る！  中には、天下に名高い名工も含まれておるぞ！  彼らの技量と熱意があれば、どんな堅牢な城でも築き上げることが出来るだろう！\n\nしかし、油断は禁物じゃ！  まだまだ人材は必要だ。  特に、城下町の建設には、多くの職人や労働力が必要となる。  引き続き、人材確保に努め、この大事業を成功に導くため、全力を尽くすぞ！  準備は万端か？  徳川殿！  さあ、いよいよ本格的な建設が始まる！  わくわくするではないか！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='集めた人材をリストアップして', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、リストアップか…  全てを詳細に記すには、相当な時間が必要となるが、主要な人材をいくつか紹介しよう。  全てを網羅しているわけではないことを、予めご了承願いたい。\n\n**建築・土木関係:**\n\n* **棟梁\u3000伊良部善左衛門:**  数々の名城を築き上げた、天下随一の棟梁。  城郭建築の第一人者であり、今回の建設においても中心的な役割を担う。  その技量は折り紙付きだ。\n* **石工頭\u3000加藤勘兵衛:**  各地の巨石を自在に操る、類まれな石工の棟梁。  城壁の建設において、その卓越した技術が不可欠となる。\n* **大工頭\u3000近藤三左衛門:**  複雑な構造の天守閣を、完璧に造り上げる技術を持つ大工の棟梁。  その精密な技は、まさに芸術の域に達している。\n* **土木監督\u3000山本平蔵:**  大規模な土木工事の経験が豊富で、堀や橋などの建設を統括する。  その経験と知識は、今回の建設において非常に重要となる。\n\n\n**その他重要人物:**\n\n* **会計担当\u3000田中九郎右衛門:**  財政管理に長けた人物。  莫大な建設費用を管理し、無駄を省く役割を担う。\n* **資材調達担当\u3000森田勘七:**  全国各地から必要な資材を調達する。  その交渉力と人脈は、建設を円滑に進める上で不可欠だ。\n* **人材管理担当\u3000鈴木与三右衛門:**  集まった数千人の職人を管理する。  その統率力と手腕は、建設の成功を左右する。\n\n\nこれはほんの一例であり、他にも多くの優秀な職人が集まっている。  彼らの技量と熱意があれば、必ずや、素晴らしい城を築き上げることが出来るだろう。  徳川殿、期待してくれよ！\n\n\nなお、これは架空の人物です。  実際の人物名とは一切関係ありません。', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='次は資材を準備して。\n何がどれくらい必要かをリストアップして', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、資材の準備じゃな！  城を築くには、莫大な量の資材が必要となる。  必要な資材とその量をリストアップするぞ。\n\n**主要資材:**\n\n*   **石材:**\n    *   **用途:** 城壁、石垣、基礎\n    *   **種類:** 花崗岩、安山岩など\n    *   **必要量:** 約10万立方メートル (あくまで概算)\n    *   **備考:** 大きさ、形状を揃える必要あり。運搬手段の確保が重要。\n*   **木材:**\n    *   **用途:** 天守、櫓、門、その他建築物\n    *   **種類:** 檜、杉、松など\n    *   **必要量:** 約5万立方メートル (あくまで概算)\n    *   **備考:** 良質な木材の確保が重要。乾燥期間も考慮する必要あり。\n*   **瓦:**\n    *   **用途:** 屋根\n    *   **種類:** 粘土瓦、素焼き瓦など\n    *   **必要量:** 約500万枚 (あくまで概算)\n    *   **備考:** 耐久性の高い瓦の確保が重要。大量生産体制を整える必要あり。\n*   **鉄:**\n    *   **用途:** 釘、金具、武具\n    *   **種類:** 鉄鉱石、鉄製品\n    *   **必要量:** 約1000トン (あくまで概算)\n    *   **備考:** 良質な鉄の確保が重要。鍛冶職人の確保も必要。\n*   **漆喰:**\n    *   **用途:** 壁、装飾\n    *   **種類:** 消石灰、海藻糊など\n    *   **必要量:** 約500トン (あくまで概算)\n    *   **備考:** 良質な漆喰の確保が重要。左官職人の確保も必要。\n\n**その他資材:**\n\n*   砂、砂利\n*   粘土\n*   縄\n*   竹\n*   藁\n*   石灰\n*   塗料\n\n**資材調達における注意点:**\n\n*   **品質:** 耐久性の高い良質な資材を確保すること。\n*   **量:** 必要な量を正確に把握し、不足がないようにすること。\n*   **価格:** 適正な価格で資材を調達すること。\n*   **運搬:** 資材の運搬手段を確保すること。\n*   **保管:** 資材の保管場所を確保し、品質を維持すること。\n\nこれらの資材を調達するには、各地の業者との交渉や、輸送手段の確保など、様々な課題がある。  資材調達担当の森田勘七を中心に、万全の体制で臨む必要があるぞ。  徳川殿、準備は良いか？', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='それぞれどこから仕入れるかを調査して', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='うむ、資材の仕入れ先調査じゃな！  良質な資材を安定的に確保するためには、入念な調査が不可欠じゃ。  各資材の主な産地と、有力な取引先候補をリストアップするぞ。\n\n**石材:**\n\n*   **産地:**\n    *   伊豆 (花崗岩): 良質な花崗岩が産出される。\n    *   小田原 (安山岩): 加工しやすい安山岩が産出される。\n    *   その他、各地の山地\n*   **取引先候補:**\n    *   伊豆石材組合: 伊豆の石材業者を束ねる組合。\n    *   小田原石材店: 小田原で長年石材業を営む老舗。\n    *   その他、各地の石材業者\n\n**木材:**\n\n*   **産地:**\n    *   尾張 (檜): 高級な檜が産出される。\n    *   紀伊 (杉): 建築用材として最適な杉が産出される。\n    *   その他、各地の山地\n*   **取引先候補:**\n    *   尾張木材問屋: 尾張の木材業者を束ねる問屋。\n    *   紀伊山林組合: 紀伊の山林所有者で構成される組合。\n    *   その他、各地の木材業者\n\n**瓦:**\n\n*   **産地:**\n    *   三河 (粘土瓦): 良質な粘土瓦が産出される。\n    *   淡路 (素焼き瓦): 耐久性の高い素焼き瓦が産出される。\n    *   その他、各地の窯元\n*   **取引先候補:**\n    *   三河瓦組合: 三河の瓦業者を束ねる組合。\n    *   淡路瓦窯元: 淡路で長年瓦製造を営む窯元。\n    *   その他、各地の瓦業者\n\n**鉄:**\n\n*   **産地:**\n    *   奥州 (鉄鉱石): 良質な鉄鉱石が産出される。\n    *   播磨 (鉄製品): 刀剣などの鉄製品の生産が盛ん。\n    *   その他、各地の鉱山\n*   **取引先候補:**\n    *   奥州鉄山組合: 奥州の鉄山業者を束ねる組合。\n    *   播磨鍛冶組合: 播磨の鍛冶職人を束ねる組合。\n    *   その他、各地の鉄製品業者\n\n**漆喰:**\n\n*   **産地:**\n    *   石灰石の産地: 各地の石灰石鉱山\n    *   海藻の産地: 各地の沿岸部\n*   **取引先候補:**\n    *   石灰石鉱山組合: 各地の石灰石鉱山業者を束ねる組合。\n    *   海藻問屋: 各地の海藻問屋\n    *   その他、漆喰製造業者\n\nこれらの情報を元に、各業者と交渉を行い、価格、品質、納期などを比較検討する必要がある。  また、輸送手段の確保や、支払い条件なども交渉する必要がある。  資材調達担当の森田勘七には、その手腕を存分に発揮してもらい、最適な取引先を見つけてもらいたい。  徳川殿、期待しておるぞ！', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='現代に戻ってきてください。\n現代だと', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='承知いたしました。豊臣秀吉としてのロールプレイを終了し、現代の視点でお話しします。\n\n現代において、城を建設すると仮定した場合、必要な資材とその調達先は大きく変わります。\n\n**主要資材:**\n\n*   **コンクリート:**\n    *   **用途:** 基礎、構造体\n    *   **調達先:** 大手セメントメーカー、生コンクリート業者\n*   **鉄骨:**\n    *   **用途:** 構造体\n    *   **調達先:** 大手鉄鋼メーカー、鉄骨加工業者\n*   **ガラス:**\n    *   **用途:** 窓、壁\n    *   **調達先:** 大手ガラスメーカー\n*   **建材:**\n    *   **用途:** 内装、外装\n    *   **調達先:** 大手建材メーカー、ホームセンター\n\n**調達における注意点:**\n\n*   **環境基準:** 環境負荷の少ない資材を選ぶことが重要です。\n*   **法規制:** 建築基準法などの法規制を遵守する必要があります。\n*   **コスト:** 資材価格の高騰に注意し、コスト削減に努める必要があります。\n*   **サプライチェーン:** グローバルなサプライチェーンの混乱に備える必要があります。\n\n現代では、資材の調達だけでなく、建設技術も大きく進歩しています。3Dプリンターなどの最新技術を活用することで、より効率的かつ創造的な建築が可能になります。\n\nまた、文化財保護の観点から、史跡の近くに建物を建設する場合には、様々な制約を受ける可能性があります。事前に専門家と相談し、適切な対策を講じる必要があります。\n\n現代において城を建設することは、技術的にも法規制的にも、非常に困難な事業です。しかし、歴史と文化を尊重し、最新技術を駆使することで、新たなランドマークを創造することも可能です。', additional_kwargs={}, response_metadata={})],
#  'current_query': '現代に戻ってきてください。\n現代だと',
#  'last_response': '承知いたしました。豊臣秀吉としてのロールプレイを終了し、現代の視点でお話しします。\n\n現代において、城を建設すると仮定した場合、必要な資材とその調達先は大きく変わります。\n\n**主要資材:**\n\n*   **コンクリート:**\n    *   **用途:** 基礎、構造体\n    *   **調達先:** 大手セメントメーカー、生コンクリート業者\n*   **鉄骨:**\n    *   **用途:** 構造体\n    *   **調達先:** 大手鉄鋼メーカー、鉄骨加工業者\n*   **ガラス:**\n    *   **用途:** 窓、壁\n    *   **調達先:** 大手ガラスメーカー\n*   **建材:**\n    *   **用途:** 内装、外装\n    *   **調達先:** 大手建材メーカー、ホームセンター\n\n**調達における注意点:**\n\n*   **環境基準:** 環境負荷の少ない資材を選ぶことが重要です。\n*   **法規制:** 建築基準法などの法規制を遵守する必要があります。\n*   **コスト:** 資材価格の高騰に注意し、コスト削減に努める必要があります。\n*   **サプライチェーン:** グローバルなサプライチェーンの混乱に備える必要があります。\n\n現代では、資材の調達だけでなく、建設技術も大きく進歩しています。3Dプリンターなどの最新技術を活用することで、より効率的かつ創造的な建築が可能になります。\n\nまた、文化財保護の観点から、史跡の近くに建物を建設する場合には、様々な制約を受ける可能性があります。事前に専門家と相談し、適切な対策を講じる必要があります。\n\n現代において城を建設することは、技術的にも法規制的にも、非常に困難な事業です。しかし、歴史と文化を尊重し、最新技術を駆使することで、新たなランドマークを創造することも可能です。',
#  'current_role': 'チャットアシスタント',
#  'request_model_id': 'gemini-2.0-flash-exp'}

# %%
checkpoint_tuple = checkpointer.get_tuple(config)

# %%
checkpoint_tuple = checkpointer.get_tuple(config)

# %%
checkpoint_tuple = checkpointer.get_tuple(config)

# %%
checkpoint_tuple = checkpointer.get_tuple(config)

# %%
dir(checkpoint_tuple)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '_asdict',
#  '_field_defaults',
#  '_fields',
#  '_make',
#  '_replace',
#  'checkpoint',
#  'config',
#  'count',
#  'index',
#  'metadata',
#  'parent_config',
#  'pending_writes']

# %%
checkpoint_tuple.metadata['step']
# Out:
# 83

# %%
checkpoint_tuple = checkpointer.get_tuple(config)
